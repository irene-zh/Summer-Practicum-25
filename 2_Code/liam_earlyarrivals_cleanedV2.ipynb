# %%
import pandas as pd
import glob
import os
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr
import statsmodels.formula.api as smf
from plotnine import *
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\Summer Practicum\\1_Data\\earlyarrivals.csv")

# %%
len(df)
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Operating_Airline   \
# 0  2022        4     10          29          6  2022-10-29                 UA
# 1  2022        4     10          29          6  2022-10-29                 UA
# 2  2022        4     10          29          6  2022-10-29                 UA
# 3  2022        4     10          29          6  2022-10-29                 UA
# 4  2022        4     10          29          6  2022-10-29                 UA
#
#    OriginAirportID Origin OriginCityName  ... DepTimeBlk CRSArrTime  ArrTime  \
# 0            11066    CMH   Columbus, OH  ...  0600-0659        828    858.0
# 1            12758    KOA       Kona, HI  ...  2100-2159        603    537.0
# 2            14747    SEA    Seattle, WA  ...  0700-0759       1609   1559.0
# 3            12889    LAS  Las Vegas, NV  ...  1900-1959       2050   2035.0
# 4            14685    SAV   Savannah, GA  ...  0600-0659        825    802.0
#
#   ArrDelay TaxiOut TaxiIn ArrTimeBlk  AirTime  Distance  CarrierDelay
# 0     30.0    12.0    7.0  0800-0859    163.0     986.0          16.0
# 1    -26.0    12.0    9.0  0600-0659    277.0    2504.0           NaN
# 2    -10.0    26.0    9.0  1600-1659    282.0    2402.0           NaN
# 3    -15.0    15.0    3.0  2000-2059     71.0     414.0           NaN
# 4    -23.0    10.0    5.0  0800-0859     94.0     708.0           NaN
#
# [5 rows x 30 columns]

# %%
date_df = df.copy()
date_df['ANext_5'] = None
date_df['ATaxi_5'] = None

# %%
date_df['ArrTime'] = date_df['ArrTime'].fillna(0).astype(int).astype(str).str.zfill(4)
date_df['FlightDate'] = pd.to_datetime(date_df['FlightDate'], format='%Y-%m-%d')
date_df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate Operating_Airline   \
# 0  2022        4     10          29          6 2022-10-29                 UA
# 1  2022        4     10          29          6 2022-10-29                 UA
# 2  2022        4     10          29          6 2022-10-29                 UA
# 3  2022        4     10          29          6 2022-10-29                 UA
# 4  2022        4     10          29          6 2022-10-29                 UA
#
#    OriginAirportID Origin OriginCityName  ... ArrTime ArrDelay  TaxiOut  \
# 0            11066    CMH   Columbus, OH  ...    0858     30.0     12.0
# 1            12758    KOA       Kona, HI  ...    0537    -26.0     12.0
# 2            14747    SEA    Seattle, WA  ...    1559    -10.0     26.0
# 3            12889    LAS  Las Vegas, NV  ...    2035    -15.0     15.0
# 4            14685    SAV   Savannah, GA  ...    0802    -23.0     10.0
#
#   TaxiIn ArrTimeBlk AirTime Distance  CarrierDelay  ANext_5  ATaxi_5
# 0    7.0  0800-0859   163.0    986.0          16.0     None     None
# 1    9.0  0600-0659   277.0   2504.0           NaN     None     None
# 2    9.0  1600-1659   282.0   2402.0           NaN     None     None
# 3    3.0  2000-2059    71.0    414.0           NaN     None     None
# 4    5.0  0800-0859    94.0    708.0           NaN     None     None
#
# [5 rows x 32 columns]

# %%
unique_ids = date_df['DestAirportID'].unique()
len(unique_ids)
# Out:
# 374

# %%
# Rolling mean for ANext_5 and ATaxi_5 for every flight
window_size = 5
step = 0
steps = len(unique_ids)
for uid in unique_ids:
    print(f"Processing ID: {uid}")
    filtered = date_df[date_df['DestAirportID'] == uid].sort_values(by = ['FlightDate', 'ArrTime'])
    
    rolling_vals = (filtered['ArrDelay'].shift(-1).rolling(window = window_size, min_periods = 1).mean().shift(-(window_size - 1)))
    rolling_vals2 = (filtered['TaxiIn'].shift(-1).rolling(window = window_size, min_periods = 1).mean().shift(-(window_size - 1)))

    date_df.loc[filtered.index, 'ANext_5'] = rolling_vals
    date_df.loc[filtered.index, 'ATaxi_5'] = rolling_vals2

    step += 1

    print(f"Step {step}/{steps} completed.")

save_df = date_df.copy()
# Out:
# Processing ID: 12266
# Step 1/374 completed.
# Processing ID: 12892
# Step 2/374 completed.
# Processing ID: 11618
# Step 3/374 completed.
# Processing ID: 14771
# Step 4/374 completed.
# Processing ID: 14027
# Step 5/374 completed.
# Processing ID: 14747
# Step 6/374 completed.
# Processing ID: 13930
# Step 7/374 completed.
# Processing ID: 12173
# Step 8/374 completed.
# Processing ID: 13495
# Step 9/374 completed.
# Processing ID: 11884
# Step 10/374 completed.
# Processing ID: 11292
# Step 11/374 completed.
# Processing ID: 14893
# Step 12/374 completed.
# Processing ID: 14492
# Step 13/374 completed.
# Processing ID: 10299
# Step 14/374 completed.
# Processing ID: 11042
# Step 15/374 completed.
# Processing ID: 13204
# Step 16/374 completed.
# Processing ID: 11540
# Step 17/374 completed.
# Processing ID: 11057
# Step 18/374 completed.
# Processing ID: 14057
# Step 19/374 completed.
# Processing ID: 14683
# Step 20/374 completed.
# Processing ID: 14908
# Step 21/374 completed.
# Processing ID: 12264
# Step 22/374 completed.
# Processing ID: 10423
# Step 23/374 completed.
# Processing ID: 14635
# Step 24/374 completed.
# Processing ID: 14107
# Step 25/374 completed.
# Processing ID: 14843
# Step 26/374 completed.
# Processing ID: 12889
# Step 27/374 completed.
# Processing ID: 13830
# Step 28/374 completed.
# Processing ID: 12016
# Step 29/374 completed.
# Processing ID: 14955
# Step 30/374 completed.
# Processing ID: 12758
# Step 31/374 completed.
# Processing ID: 14122
# Step 32/374 completed.
# Processing ID: 14689
# Step 33/374 completed.
# Processing ID: 12953
# Step 34/374 completed.
# Processing ID: 14679
# Step 35/374 completed.
# Processing ID: 14262
# Step 36/374 completed.
# Processing ID: 10849
# Step 37/374 completed.
# Processing ID: 11066
# Step 38/374 completed.
# Processing ID: 14831
# Step 39/374 completed.
# Processing ID: 10529
# Step 40/374 completed.
# Processing ID: 14457
# Step 41/374 completed.
# Processing ID: 10994
# Step 42/374 completed.
# Processing ID: 14321
# Step 43/374 completed.
# Processing ID: 11298
# Step 44/374 completed.
# Processing ID: 13871
# Step 45/374 completed.
# Processing ID: 10721
# Step 46/374 completed.
# Processing ID: 10800
# Step 47/374 completed.
# Processing ID: 13230
# Step 48/374 completed.
# Processing ID: 11278
# Step 49/374 completed.
# Processing ID: 14869
# Step 50/374 completed.
# Processing ID: 14986
# Step 51/374 completed.
# Processing ID: 10397
# Step 52/374 completed.
# Processing ID: 10693
# Step 53/374 completed.
# Processing ID: 11697
# Step 54/374 completed.
# Processing ID: 11775
# Step 55/374 completed.
# Processing ID: 11986
# Step 56/374 completed.
# Processing ID: 10713
# Step 57/374 completed.
# Processing ID: 10731
# Step 331/374 completed.
# Processing ID: 12007
# Step 332/374 completed.
# Processing ID: 11308
# Step 333/374 completed.
# Processing ID: 10577
# Step 334/374 completed.
# Processing ID: 14222
# Step 335/374 completed.
# Processing ID: 14905
# Step 336/374 completed.
# Processing ID: 14259
# Step 337/374 completed.
# Processing ID: 14025
# Step 338/374 completed.
# Processing ID: 12223
# Step 339/374 completed.
# Processing ID: 10158
# Step 340/374 completed.
# Processing ID: 12898
# Step 341/374 completed.
# Processing ID: 12819
# Step 342/374 completed.
# Processing ID: 10551
# Step 343/374 completed.
# Processing ID: 12523
# Step 344/374 completed.
# Processing ID: 10754
# Step 345/374 completed.
# Processing ID: 15991
# Step 346/374 completed.
# Processing ID: 10926
# Step 347/374 completed.
# Processing ID: 14828
# Step 348/374 completed.
# Processing ID: 14256
# Step 349/374 completed.
# Processing ID: 15841
# Step 350/374 completed.
# Processing ID: 11630
# Step 351/374 completed.
# Processing ID: 13873
# Step 352/374 completed.
# Processing ID: 13970
# Step 353/374 completed.
# Processing ID: 10170
# Step 354/374 completed.
# Processing ID: 10165
# Step 355/374 completed.
# Processing ID: 14004
# Step 356/374 completed.
# Processing ID: 14709
# Step 357/374 completed.
# Processing ID: 14303
# Step 358/374 completed.
# Processing ID: 10275
# Step 359/374 completed.
# Processing ID: 10245
# Step 360/374 completed.
# Processing ID: 11470
# Step 361/374 completed.
# Processing ID: 16101
# Step 362/374 completed.
# Processing ID: 11336
# Step 363/374 completed.
# Processing ID: 15356
# Step 364/374 completed.
# Processing ID: 10617
# Step 365/374 completed.
# Processing ID: 12320
# Step 366/374 completed.
# Processing ID: 13829
# Step 367/374 completed.
# Processing ID: 11274
# Step 368/374 completed.
# Processing ID: 10272
# Step 369/374 completed.
# Processing ID: 13832
# Step 370/374 completed.
# Processing ID: 13344
# Step 371/374 completed.
# Processing ID: 11997
# Step 372/374 completed.
# Processing ID: 10643
# Step 373/374 completed.
# Processing ID: 10590
# Step 374/374 completed.

# %%
date_df.head(1)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate Operating_Airline   \
# 0  2022        4     10          29          6 2022-10-29                 UA
#
#    OriginAirportID Origin OriginCityName  ... ArrTime ArrDelay  TaxiOut  \
# 0            11066    CMH   Columbus, OH  ...    0858     30.0     12.0
#
#   TaxiIn ArrTimeBlk AirTime Distance  CarrierDelay  ANext_5  ATaxi_5
# 0    7.0  0800-0859   163.0    986.0          16.0     27.4      8.4
#
# [1 rows x 32 columns]

# %% [markdown]
# **Primer code for graphs**

# %%
# All airports
date_df['ArrDelayBlk'] = (date_df['ArrDelay']//5)*5
date_df[['ArrDelay', 'ArrDelayBlk']].head(5)

ADB_VC = date_df['ArrDelayBlk'].value_counts()

# %% [markdown]
# **Select one of the following**

# %%
date_df = save_df.copy()
len(date_df)

# Alaska Airlines - AS
as_df = date_df[date_df['Operating_Airline '] == "AS"].copy()
len(as_df)

# JetBlue - B6
b6_df = date_df[date_df['Operating_Airline '] == "B6"].copy()
len(b6_df)

# Allegiant Air - G4
g4_df = date_df[date_df['Operating_Airline '] == "G4"].copy()
len(g4_df)

# Frontier Airlines - F9
f9_df = date_df[date_df['Operating_Airline '] == "F9"].copy()
len(f9_df)
# Out:
# 155725

# %%
#airline_dfs = [as_df, b6_df, g4_df, f9_df]
#op_airlines = ["AS", "B6", "G4", "F9"]

# %%
airline_dfs = [date_df]
op_airlines = ["ALL"]
limit = 20
dfs = {}

for op_airlines, df in zip(op_airlines, airline_dfs):
    df['ArrDelayBlk'] = (df['ArrDelay']//5)*5
    arrdelayblk_grouped_avg2 = df.groupby(['ArrDelayBlk']).agg(ANext_5 = ('ANext_5', 'mean'), count = ('ArrDelayBlk', 'count')).reset_index()
    dfs[f'{op_airlines}'] = arrdelayblk_grouped_avg2[arrdelayblk_grouped_avg2['count'] >= limit]

len(dfs)
# Out:
# 1

# %% [markdown]
# **Zoom for graph**
#
# Select your conditions/range

# %%
# Full range

for airline, df in dfs.items():
    dfs[airline] = df[(df['ArrDelayBlk'] <= 2000)].copy()

# %%
# Between -100 and 750

for airline, df in dfs.items():
    dfs[airline] = df[(df['ArrDelayBlk'] <= 750) & (df['ArrDelayBlk']  >= -100)].copy()

# %%
# Between -50 and 200

for airline, df in dfs.items():
    dfs[airline] = df[(df['ArrDelayBlk'] <= 200) & (df['ArrDelayBlk']  >= -50)].copy()

# %%
# Combining the dataframes for plotting

df_list = []

for airline, df in dfs.items():
    temp_df = df.copy()
    temp_df['Airline'] = airline
    df_list.append(temp_df)

combined_df = pd.concat(df_list, ignore_index=True)

# %% [markdown]
# **Create the graph**

# %% [markdown]
# Red - #9C2C19
#
# Blue - #0F6391
#
# Pink - #E19B8C
#
# Orange - #CB5017
#
# Light Blue - #1E8ABC

# %%
custom_palette = {
    'AS': '#0F6391',
    'B6': '#9C2C19',
    'G4': '#E19B8C',
    'F9': '#CB5017',
    'ALL': 'black'
}

# %%
categories = combined_df['Airline'].unique()

plt.figure(figsize = (12,9))

for airline in combined_df['Airline'].unique():

    alpha = 1.0 if airline == 'ALL' else 1.0

    sns.scatterplot(data = combined_df[combined_df['Airline'] == airline],
                    x = 'ArrDelayBlk', y = 'ANext_5', alpha = alpha, color = custom_palette[airline], s = 100, label = airline)

plt.ylim([-10, 50])
plt.xlim([-60, 210])
plt.legend()
plt.title("Arrival Delays vs. Next 5 Arrival Delays")
plt.xlabel("Arrival Delay (Minutes)")
plt.ylabel("Average Delay of Next 5 Arrivals (Minutes)")

plt.show()

# %%
plt.figure(figsize=(12,9))
plt.rcParams.update({'font.size':20})
sns.scatterplot(data = combined_df, x = "ArrDelayBlk", y = "ANext_5", hue='Airline', palette = custom_palette, s = 150)
plt.title("Arrival Delays vs. Next 5 Arrival Delays")
plt.xlabel("Arrival Delay (Minutes)")
plt.ylabel("Average Delay of Next 5 Arrivals (Minutes)")

plt.show()

# %% [markdown]
# "We've developed a quantized representation of arrival delays vs the delayed rolling mean of 5 consecutive arrival delays"
#
# "This visual solidifies the fact that as the arrival delay increases, a ripple effect of delays is felt throughout the system, and thus we have decided to weight the frequency of delays over the average length of delay in our scoring model due to the impact of one airline's performance onto other airlines."

# %% [markdown]
# ***Modeling Section***
#
# Attempting to create a model for predicting consequent delays based on arrival time
